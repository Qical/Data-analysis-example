# %%
import jieba
import jieba.posseg as pseg # 统计词性
import pandas as pd
import re
from collections import Counter # 用于字典类型的计数
import os
# 确定我的操作目录
os.chdir(r"C:\Users\Administrator\Desktop\爬虫\GitHub\Jay")

# 生成echarts类库表的调用
from pyecharts.globals import SymbolType
from pyecharts.charts import Bar,WordCloud

# 读取下载好的文件
df = pd.read_csv("Jay_comment_data.csv")
# 将评论这一列提取出来并且转换成列表,\
# 这里需要注意的是df[].values是ndarray的格式，还需要添加tolist()的方法
comment_list = df['comment'].values.tolist()

# 创建字典，拆词计数
word_dict = {}

for line in comment_list:
    words = jieba.cut(line) #这里的word是迭代器
    for word in words:
        if word not in word_dict:
            word_dict[word] = 1
        else:
            word_dict[word] += 1

# 处理分词
stop_word = pd.read_csv("Chinese_Stopwords.txt",encoding='utf-8',header = None)
# 因为是pandas读取，帮其更新相应的列名
stop_word.columns = ['word']
stop_word = [' '] +list(stop_word['word'])

# 将常用的“废词”去掉
for i in range(len(stop_word)):
    if stop_word[i] in word_dict:
        word_dict.pop(stop_word[i])

# 按照词频出现的次数进行排序,sorted要传入一个可迭代的对象，所以使用word_dict.items()构建列表
word_dict_sort = sorted(word_dict.items(),key = lambda x:x[1],reverse=True )

# 取前100的词频
word = word_dict_sort[:100]
# print(word)
# 制作词云图
wordcloud = WordCloud()
# 添加注释(不知道什么原因(可能emoji)，这个是无法绘出图形)
wordcloud.add("",words,word_size_range=[20,100],shape='circle')
wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="dd7952b693db41bf90a7a4756de3a59d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_dd7952b693db41bf90a7a4756de3a59d = echarts.init(
#                     document.getElementById('dd7952b693db41bf90a7a4756de3a59d'), 'white', {renderer: 'canvas'});
#                 var option_dd7952b693db41bf90a7a4756de3a59d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": []
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     }
# };
#                 chart_dd7952b693db41bf90a7a4756de3a59d.setOption(option_dd7952b693db41bf90a7a4756de3a59d);
#         });
#     </script>

# %%
# 进行词性分类
def speech_cut(speech):
    word_list =[]
    for word in word_dict_sort:
        words = pseg.cut(word[0])
        for w,flag in words:
            if flag == speech:
                word_list.append(word)
    return word_list

# 动词 V
verb_word = speech_cut('v')
wordcloud = WordCloud()
wordcloud.add("",verb_word[:100],word_size_range=[20,100],shape='circle')
wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="dd804ff708cf4565aafecc84a89886d7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_dd804ff708cf4565aafecc84a89886d7 = echarts.init(
#                     document.getElementById('dd804ff708cf4565aafecc84a89886d7'), 'white', {renderer: 'canvas'});
#                 var option_dd804ff708cf4565aafecc84a89886d7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u542c",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,72,109)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u6b22",
#                     "value": 513,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,53,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bf4",
#                     "value": 399,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,151,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7231",
#                     "value": 349,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,124,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": 326,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,35,129)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bf4\u597d",
#                     "value": 323,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,110,18)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54ed",
#                     "value": 309,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,137,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d\u542c",
#                     "value": 297,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,96,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u54ed",
#                     "value": 263,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,68,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u60f3",
#                     "value": 259,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,132,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f1a",
#                     "value": 240,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,115,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e0c\u671b",
#                     "value": 235,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,35,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u77e5\u9053",
#                     "value": 211,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,77,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e70",
#                     "value": 210,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,139,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u613f\u610f",
#                     "value": 185,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,43,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u652f\u6301",
#                     "value": 169,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,136,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1",
#                     "value": 138,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,68,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a0\u6cb9",
#                     "value": 135,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,58,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89c9\u5f97",
#                     "value": 119,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,109,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u671f\u5f85",
#                     "value": 92,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,142,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u542c\u5230",
#                     "value": 92,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,159,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56de\u5fc6",
#                     "value": 89,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,154,64)"
#                         }
#                     }

# %%
# 名词 n
verb_word = speech_cut('n')
# print(verb_word)
wordcloud = WordCloud()
wordcloud.add("",verb_word[:100],word_size_range=[20,100],shape='circle')
wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="ea77287c8e1d4c7b9c9c8697925c7b5a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_ea77287c8e1d4c7b9c9c8697925c7b5a = echarts.init(
#                     document.getElementById('ea77287c8e1d4c7b9c9c8697925c7b5a'), 'white', {renderer: 'canvas'});
#                 var option_ea77287c8e1d4c7b9c9c8697925c7b5a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u6f14\u5531\u4f1a",
#                     "value": 470,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,109,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b4c",
#                     "value": 469,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,152,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u97f3\u4e50",
#                     "value": 441,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,127,104)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e26\u4f60\u53bb",
#                     "value": 292,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,143,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u6b4c",
#                     "value": 213,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,145,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e13\u8f91",
#                     "value": 190,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,133,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": 169,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,81,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9996\u6b4c",
#                     "value": 152,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,72,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5076\u50cf",
#                     "value": 113,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,11,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5355\u66f2",
#                     "value": 100,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,9,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65f6\u95f4",
#                     "value": 94,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,119,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b4c\u8bcd",
#                     "value": 92,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,97,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65f6",
#                     "value": 86,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,103,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 83,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(47,146,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u94b1",
#                     "value": 82,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,5,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7c89\u4e1d",
#                     "value": 81,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,25,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b4c\u624b",
#                     "value": 79,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,79,129)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bc4\u8bba",
#                     "value": 78,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,75,86)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7816",
#                     "value": 78,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,134,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65f6\u4ee3",
#                     "value": 75,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,82,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u540d",
#                     "value": 74,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,140,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2a\u6027",
#                     "value": 74,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,75,77)"
#                         }

# %%
# 表情分析,爬下来的文本会有emoji，我们需要将其过选出来
"""
具体的mysql的处理方式可以通过如下的链接查看
https://blog.csdn.net/weixin_42812527/article/details/81876713
有时需要过滤掉四字节以上的字符（表情），比如MySQL数据库5.5.3以下的版本text字段不支持四字节以上字符
"""

def get_emoji(content):
    pattern = re.compile(u"[\U00010000-\U0010ffff]")
    result = re.findall(pattern,content)
    return result

# apply的传参方法需要注意一下：
df['emojis_list'] = df['comment'].apply(get_emoji)
# 转变成列表(没有emoji就是空列表，有emoji就是emoji表情
# eg:[[], [], ['😭'], ['😘'], [], [], [], ['😍'], ['😭'], ['🌹', '🌹', '🌹', '🌹']]
emojis = df['emojis_list'].values.tolist()

# 这个地方妙用了sum的方法，给例表实现了降维，并且去掉了空列表[],本应该用join的方式来实现
# https://blog.csdn.net/BF02jgtRS00XKtCx/article/details/89484064可以大致参考这个博客进行查看
emojis_list = sum(emojis,[])

# 对列表的元素进行计数，并且生成字典
# eg: {'😭': 261, '😍': 83, '😃': 79, '😂': 69, '👍': 67}
counter = Counter(emojis_list)
# most_common([n]):http://www.pythoner.com/205.html
# 返回一个TopN列表。如果n没有被指定，则返回所有元素。当多个元素计数值相同时，排列是无确定顺序的。
y_emojis, x_counts = zip(*counter.most_common())
bar = Bar()
bar.add_xaxis(y_emojis[:20])
bar.add_yaxis("", x_counts[:20])
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="238b0b4b466f4820acafa861326f0302" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_238b0b4b466f4820acafa861326f0302 = echarts.init(
#                     document.getElementById('238b0b4b466f4820acafa861326f0302'), 'white', {renderer: 'canvas'});
#                 var option_238b0b4b466f4820acafa861326f0302 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 261,
#                 83,
#                 79,
#                 69,
#                 67,
#                 59,
#                 50,
#                 50,
#                 45,
#                 38,
#                 34,
#                 33,
#                 32,
#                 24,
#                 23,
#                 22,
#                 22,
#                 21,
#                 20,
#                 18
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\ud83d\ude2d",
#                 "\ud83d\ude0d",
#                 "\ud83d\ude03",
#                 "\ud83d\ude02",
#                 "\ud83d\udc4d",
#                 "\ud83c\udf39",
#                 "\ud83d\ude0a",
#                 "\ud83d\ude33",
#                 "\ud83d\ude0e",
#                 "\ud83d\ude1a",
#                 "\ud83c\udf89",
#                 "\ud83d\ude04",
#                 "\ud83d\ude01",
#                 "\ud83d\udc96",
#                 "\ud83d\ude48",
#                 "\ud83d\ude0f",
#                 "\ud83d\udc4f",
#                 "\ud83d\udd7a",
#                 "\ud83d\ude1c",
#                 "\ud83d\udc8e"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_238b0b4b466f4820acafa861326f0302.setOption(option_238b0b4b466f4820acafa861326f0302);
#         });
#     </script>
